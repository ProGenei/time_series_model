# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/MiniProjectWeek5/Datasets'
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-20-664fcea15a6f>", line 3, in <cell line: 3>
#     get_ipython().run_line_magic('cd', "'/content/drive/My Drive/MiniProjectWeek5/Datasets'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('traffic_dataset_with_trend (1).csv', parse_dates=['Timestamp'])
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-21-26c35d42a828>", line 1, in <cell line: 1>
#     df = pd.read_csv('traffic_dataset_with_trend (1).csv', parse_dates=['Timestamp'])
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 948, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 611, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
# ...

# %%
df.isnull().sum()
# Out:
# Weather           0
# Events            0
# Traffic Volume    0
# dtype: int64

# %%
df['Events'].unique()
# Out:
# array([False,  True])

# %%
df.duplicated().sum()
# Out:
# 4861

# %%
df.head()
# Out:
#                     Weather  Events  Traffic Volume
# Timestamp
# 2023-01-01 00:00:00  Cloudy   False           803.0
# 2023-01-01 01:00:00   Clear   False           861.0
# 2023-01-01 02:00:00   Clear   False           582.0
# 2023-01-01 03:00:00  Cloudy   False           236.0
# 2023-01-01 04:00:00  Cloudy   False           569.0

# %% [markdown]
# EDA between traffic volume and Events (correlation)

# %%
df = df.set_index('Timestamp')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-25-d4365db42d11>", line 1, in <cell line: 1>
#     df = df.set_index('Timestamp')
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 5870, in set_index
#     raise KeyError(f"None of {missing} are in the columns")
# KeyError: "None of ['Timestamp'] are in the columns"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8736 entries, 2023-01-01 00:00:00 to 2023-12-30 23:00:00
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Weather         8736 non-null   object
#  1   Events          8736 non-null   bool
#  2   Traffic Volume  8736 non-null   float64
# dtypes: bool(1), float64(1), object(1)
# memory usage: 213.3+ KB

# %%
df.values #this is what the machine see
# Out:
# array([['Cloudy', False, 803.0],
#        ['Clear', False, 861.0],
#        ['Clear', False, 582.0],
#        ...,
#        ['Cloudy', False, 833.0],
#        ['Clear', False, 740.0],
#        ['Clear', False, 825.0]], dtype=object)

# %%
df.index
# Out:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-01-01 01:00:00',
#                '2023-01-01 02:00:00', '2023-01-01 03:00:00',
#                '2023-01-01 04:00:00', '2023-01-01 05:00:00',
#                '2023-01-01 06:00:00', '2023-01-01 07:00:00',
#                '2023-01-01 08:00:00', '2023-01-01 09:00:00',
#                ...
#                '2023-12-30 14:00:00', '2023-12-30 15:00:00',
#                '2023-12-30 16:00:00', '2023-12-30 17:00:00',
#                '2023-12-30 18:00:00', '2023-12-30 19:00:00',
#                '2023-12-30 20:00:00', '2023-12-30 21:00:00',
#                '2023-12-30 22:00:00', '2023-12-30 23:00:00'],
#               dtype='datetime64[ns]', name='Timestamp', length=8736, freq=None)

# %%
df.index = pd.to_datetime(df.index)
window = 2

plt.figure(figsize=(15, 6))
plt.plot(df.index, df['Traffic Volume'], label='Traffic Volume', linewidth=2)
plt.plot(df.index, df['Traffic Volume'].rolling(window=window).mean(), label=f'{window}-Day Moving Avg', linestyle='--')
plt.title(f'Closing Prices and {window}-Day Moving Average')
plt.xlabel('DateTime')
plt.ylabel('Traffic Volume')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
train = df.loc['2023-01-01':'2023-09-30']
val = df.loc['2023-10-01':'2023-11-15']
test = df.loc['2023-11-16':'2023-12-30']

# %%
train.shape, val.shape, test.shape
# Out:
# ((6552, 3), (1104, 3), (1080, 3))

# %%
from sklearn.model_selection import train_test_split

train_val, test = train_test_split(df, test_size=1080, shuffle=False)
train, val = train_test_split(train_val, test_size=1104, shuffle=False)

# %%
train.shape, val.shape, test.shape
# Out:
# ((6552, 3), (1104, 3), (1080, 3))

# %% [markdown]
# Another way to split your data

# %%
730 / df.shape[0]
# Out:
# 0.08356227106227106

# %%
train.shape, val.shape, test.shape
# Out:
# ((6552, 3), (1104, 3), (1080, 3))

# %% [markdown]
# When we have one column, no need in ml to scale data, in dl scale it between 0 - 1

# %%
# pipeline and scaler in pipeline

# %%
train.columns
# Out:
# Index(['Weather', 'Events', 'Traffic Volume'], dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

preprocessing_pipeline = make_column_transformer( #it will drop the columns I don't put in
    (MinMaxScaler(), ['Traffic Volume']),
    (OneHotEncoder(), ['Weather', 'Events'])
)

# %%
train_pre = preprocessing_pipeline.fit_transform(train)
val_pre = preprocessing_pipeline.transform(val)
test_pre = preprocessing_pipeline.transform(test)

# %%
train_pre.shape # one hot encoding: 3 new columns because of W, A, U to numerical
# Out:
# (6552, 7)

# %%
train_pre
# Out:
# array([[0.107925  , 0.        , 1.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.11706318, 1.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.0731054 , 1.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.31621238, 1.        , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.16637782, 0.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.14022373, 0.        , 0.        , ..., 0.        , 1.        ,
#         0.        ]])

# %%
from tensorflow.keras.utils import timeseries_dataset_from_array
window_size = 30

train_Xy = timeseries_dataset_from_array(train_pre, targets=train_pre[window_size:, 0], sequence_length = window_size, batch_size=1024)
val_Xy = timeseries_dataset_from_array(val_pre, targets=val_pre[window_size:, 0], sequence_length = window_size, batch_size=1024)
test_Xy = timeseries_dataset_from_array(test_pre, targets=val_pre[window_size:, 0], sequence_length = window_size, batch_size=1024)

# %% [markdown]
# Example

# %% [markdown]
# Splitting the X, Y's

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
# input_shape=()
model = Sequential([
    SimpleRNN(50, activation='tanh', return_sequences=True),
    SimpleRNN(30, activation='tanh'),
    Dense(1, activation='relu')
])

model.compile(optimizer='adam', loss='mae', metrics=['mae'])

history = model.fit(train_Xy, validation_data=val_Xy, epochs=20, batch_size=128)
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - loss: 0.1781 - mae: 0.1781 - val_loss: 0.1831 - val_mae: 0.1831
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - loss: 0.1665 - mae: 0.1665 - val_loss: 0.1368 - val_mae: 0.1368
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - loss: 0.1226 - mae: 0.1226 - val_loss: 0.0986 - val_mae: 0.0986
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - loss: 0.0953 - mae: 0.0953 - val_loss: 0.0862 - val_mae: 0.0862
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - loss: 0.0795 - mae: 0.0795 - val_loss: 0.0684 - val_mae: 0.0684
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 333ms/step - loss: 0.0704 - mae: 0.0704 - val_loss: 0.0677 - val_mae: 0.0677
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - loss: 0.0687 - mae: 0.0687 - val_loss: 0.0642 - val_mae: 0.0642
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - loss: 0.0663 - mae: 0.0663 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 9/20
# ...

# %%
val_pre.shape
# Out:
# (730, 1)

# %% [markdown]
# **No relationship with the inputs (Dense)**

# %%
history.history
# Out:
# {'loss': [0.2571844160556793,
#   0.24589617550373077,
#   0.23518483340740204,
#   0.22501380741596222,
#   0.21542435884475708,
#   0.20648536086082458,
#   0.19820837676525116],
#  'mae': [0.4472476541996002,
#   0.4347866475582123,
#   0.42283445596694946,
#   0.41134926676750183,
#   0.40038424730300903,
#   0.3900116980075836,
#   0.38024967908859253],
#  'val_loss': [0.17095914483070374,
#   0.16296710073947906,
#   0.15549661219120026,
#   0.14853467047214508,
#   0.14210224151611328,
#   0.13616099953651428,
#   0.13073432445526123],
#  'val_mae': [0.36641693115234375,
#   0.3555043041706085,
#   0.3451102674007416,
#   0.335277259349823,
#   0.32607442140579224,
#   0.3174649178981781,
#   0.3094615936279297]}

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
model.evaluate(val_Xy) #mae
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0612 - mae: 0.0612
# [0.06147221103310585, 0.06147221103310585]

# %%
X_val, y_val = next(iter(val_Xy))

# %%
y_pred = model.predict(X_val)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
y_pred.shape
# Out:
# (700, 30, 1)

# %%
y_pred = model.predict(val_Xy)
y_pred
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step
# array([[0.1373339 ],
#        [0.15500577],
#        [0.16408786],
#        ...,
#        [0.13869162],
#        [0.16575451],
#        [0.15980944]], dtype=float32)

# %%
# Simulated data for the example (continued)
dates = np.arange('2020-01', '2024-01', dtype='datetime64[D]')
traffic_volume = np.random.rand(len(dates)) * 1000  # Simulated traffic volume data
new_df = np.array(traffic_volume).reshape(-1, 1)

# Scaler (assuming MinMaxScaler was used in preprocessing)
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(new_df)

# Simulated predictions (train and test)

# Set the number of previous time steps to consider for plotting
look_back = 0

# Initialize an array for plotting the train predictions
trainPredictPlot = np.empty_like(scaled_data)
trainPredictPlot[:, :] = np.nan
# Assign the predicted values to the appropriate location for train predictions
trainPredictPlot[look_back:len(train_pre) + look_back, 0] = train_pre.flatten()

# Initialize an array for plotting the test predictions
testPredictPlot = np.empty_like(scaled_data)
testPredictPlot[:, :] = np.nan
# Calculate the starting index for the test predictions
test_start = len(new_df) - len(test_pre)
# Assign the predicted values to the appropriate location for test predictions
testPredictPlot[test_start:, 0] = test_pre.flatten()

# Rescale the scaled data back to its original scale using the scaler
original_scaled_data = scaler.inverse_transform(scaled_data)

# Plotting the baseline data, training predictions, and test predictions
plt.figure(figsize=(15, 6))
plt.plot(dates, original_scaled_data, color='black', label="Actual Traffic Volume")
plt.plot(dates, trainPredictPlot, color='red', label="Predicted Traffic Volume (train set)")
plt.plot(dates, testPredictPlot, color='blue', label="Predicted Traffic Volume (test set)")

plt.title("Traffic Volume Predictions")
plt.xlabel("Time")
plt.ylabel("Traffic Volume")
plt.legend()
plt.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-49-fd36a5ebe28e>", line 19, in <cell line: 19>
#     trainPredictPlot[look_back:len(train_pre) + look_back, 0] = train_pre.flatten()
# ValueError: could not broadcast input array from shape (45864,) into shape (1461,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your original dataframe with a datetime index
# If it's not, you'll need to set the index to datetime first

# Create a copy of the dataframe with only the 'Traffic Volume' column
df_plot = df[['Traffic Volume']].copy()

# Add columns to indicate which set each row belongs to
df_plot['Set'] = 'Train'
df_plot.loc[train.index[-1]+pd.Timedelta(seconds=1):val.index[-1], 'Set'] = 'Validation'
df_plot.loc[val.index[-1]+pd.Timedelta(seconds=1):, 'Set'] = 'Test'

# Set up the plot
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

# Plot each set
sns.lineplot(data=df_plot, x=df_plot.index, y='Traffic Volume', hue='Set',
             palette={'Train': 'blue', 'Validation': 'green', 'Test': 'red'})

# Customize the plot
plt.title('Traffic Volume Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Traffic Volume', fontsize=12)
plt.legend(title='Dataset', title_fontsize=12, fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your original dataframe with a datetime index
# If it's not, you'll need to set the index to datetime first

# Create a copy of the dataframe with only the 'Traffic Volume' column
df_plot = df[['Traffic Volume']].copy()

# Add columns to indicate which set each row belongs to
df_plot['Set'] = 'Train'
df_plot.loc[train.index[-1]+pd.Timedelta(seconds=1):val.index[-1], 'Set'] = 'Validation'
df_plot.loc[val.index[-1]+pd.Timedelta(seconds=1):, 'Set'] = 'Test'

# Set up the plot
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

# Plot each set
sns.lineplot(data=df_plot, x=df_plot.index, y='Traffic Volume', hue='Set',
             palette={'Train': 'blue', 'Validation': 'green', 'Test': 'red'})

# Customize the plot
plt.title('Traffic Volume Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Traffic Volume', fontsize=12)
plt.legend(title='Dataset', title_fontsize=12, fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.inverse_transform(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-49-71d87387babf> in <cell line: 4>()
#       2
#       3 scaler = MinMaxScaler()
# ----> 4 scaler.inverse_transform(y_pred)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#     540             Transformed data.
#     541         """
# --> 542         check_is_fitted(self)
#     543
#     544         X = check_array(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1459
#    1460     if not _is_fitted(estimator, attributes, all_or_any):
# -> 1461         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1462
#    1463
#
# NotFittedError: This MinMaxScaler instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
y_pred.shape
# Out:
# (700, 30, 1)

# %%
type(train_Xy)
# Out:
# tensorflow.python.data.ops.batch_op._BatchDataset

# %%
scaler.inverse_transform(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-2c57ad70cbf9> in <cell line: 1>()
# ----> 1 scaler.inverse_transform(y_pred)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#     542         check_is_fitted(self)
#     543
# --> 544         X = check_array(
#     545             X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     546         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     949             )
#     950         if not allow_nd and array.ndim >= 3:
# --> 951             raise ValueError(
#     952                 "Found array with dim %d. %s expected <= 2."
# ...

# %% [markdown]
# **Relationship with the inputs (RNN)**

# %%
model.evaluate(val_Xy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.1495 - mae: 0.1495
# [0.14947918057441711, 0.14947918057441711]

# %%
y_pred = model.predict(val_Xy)
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# array([[0.6507451 ],
#        [0.61478466],
#        [0.71226543],
#        [0.58515733],
#        [0.37097105],
#        [0.39245978],
#        [0.59178704],
#        [0.65601194],
#        [0.6061824 ],
#        [0.6096486 ],
#        [0.5105028 ],
#        [0.27369058],
#        [0.42571253],
#        [0.4943354 ],
#        [0.6714358 ],
#        [0.7051444 ],
#        [0.6717776 ],
#        [0.60480064],
#        [0.3906921 ],
#        [0.5847242 ],
#        [0.4425669 ],
#        [0.6422077 ],
#        [0.7523261 ],
#        [0.7250936 ],
#        [0.5992458 ],
#        [0.43224335],
#        [0.32685673],
#        [0.5418872 ],
#        [0.6762648 ],
#        [0.74945575],
#        [0.7738883 ],
#        [0.6775103 ],
#        [0.5766457 ],
#        [0.41532496],
#        [0.7345803 ],
#        [0.5638715 ],
#        [0.59796494],
#        [0.75148773],
#        [0.49752966],
#        [0.59726936],
#        [0.3100603 ],
# ...

# %%
y_pred.shape
# Out:
# (700, 1)

# %% [markdown]
# **LSTM**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM
# input_shape=()
model = Sequential([
    LSTM(50, activation='tanh', return_sequences=True),
    LSTM(30, activation='tanh'),
    Dense(1, activation='relu')
])

model.compile(optimizer='adam', loss='mae', metrics=['mae'])

history = model.fit(train_Xy, validation_data=val_Xy, epochs=20, batch_size=128)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU
# input_shape=()
model = Sequential([
    GRU(50, activation='tanh', return_sequences=True),
    GRU(30, activation='tanh'),
    Dense(1, activation='relu')
])

model.compile(optimizer='adam', loss='mae', metrics=['mae'])

history = model.fit(train_Xy, validation_data=val_Xy, epochs=20, batch_size=128)

# %% [markdown]
# ## Multi predict 2 numbers

# %%
from tensorflow.keras.utils import timeseries_dataset_from_array
window_size = 30

train_Xy = timeseries_dataset_from_array(train_pre, targets=train_pre[window_size:, 0:2], sequence_length = window_size, batch_size=1024)
val_Xy = timeseries_dataset_from_array(val_pre, targets=val_pre[window_size:, 0:2], sequence_length = window_size, batch_size=1024)
test_Xy = timeseries_dataset_from_array(test_pre, targets=val_pre[window_size:, 0:2], sequence_length = window_size, batch_size=1024)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
# input_shape=()
model = Sequential([
    SimpleRNN(50, activation='tanh', return_sequences=True),
    SimpleRNN(30, activation='tanh'),
    Dense(2, activation='relu')
])

model.compile(optimizer='adam', loss='mae', metrics=['mae'])

history = model.fit(train_Xy, validation_data=val_Xy, epochs=20, batch_size=128)
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 213ms/step - loss: 0.4523 - mae: 0.4523 - val_loss: 0.3289 - val_mae: 0.3289
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.2925 - mae: 0.2925 - val_loss: 0.2574 - val_mae: 0.2574
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - loss: 0.2834 - mae: 0.2834 - val_loss: 0.1749 - val_mae: 0.1749
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - loss: 0.1718 - mae: 0.1718 - val_loss: 0.1531 - val_mae: 0.1531
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - loss: 0.1372 - mae: 0.1372 - val_loss: 0.1113 - val_mae: 0.1113
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.1558 - mae: 0.1558 - val_loss: 0.1618 - val_mae: 0.1618
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - loss: 0.1086 - mae: 0.1086 - val_loss: 0.1011 - val_mae: 0.1011
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.1004 - mae: 0.1004 - val_loss: 0.1228 - val_mae: 0.1228
# Epoch 9/20
# ...
